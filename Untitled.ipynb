# %%
import tensorflow as tf
from sklearn.utils import resample
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from math import pow
import pandas as pd
import seaborn as sns

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

X_train = X_train.reshape(len(X_train), -1)
y_train = y_train.reshape(len(y_train))

X_test = X_test.reshape(len(X_test), -1)
y_test = y_test.reshape(len(y_test))

X_train, y_train = resample(X_train, y_train, random_state=0, n_samples=10000)
X_test, y_test = resample(X_test, y_test, random_state=0, n_samples=1000)

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((10000, 784), (10000,), (1000, 784), (1000,))

# %%
svc = SVC()
svc.fit(X_train, y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
y_pred = svc.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.792

# %%
def cs():
    for e in range(-5, 5+1):
        for b in 1,:
            yield b * pow(10, e)

# %%
list(cs())
# Out:
# [1e-05, 0.0001, 0.001, 0.01, 0.1, 1.0, 10.0, 100.0, 1000.0, 10000.0, 100000.0]

# %%
def gen():
    for C in cs():
        for kernel in 'linear', 'poly', 'rbf', 'sigmoid':
            svc = SVC(C=C, kernel=kernel)
            svc.fit(X_train, y_train)  
            y_pred = svc.predict(X_test)
            accuracy = accuracy_score(y_test, y_pred)
            print(C, kernel, accuracy)
            yield C, kernel, accuracy
            
results = pd.DataFrame(gen(), columns=['C', 'kernel', 'accuracy'])
# Out:
# 1e-05 linear 0.826

# %%
results.sort_values(by='accuracy', ascending=False)
# Out:
#                C   kernel  accuracy
# 0        0.00001   linear     0.791
# 1        0.00001     poly     0.080
# 2        0.00001      rbf     0.080
# 3        0.00001  sigmoid     0.080
# 4        0.00010   linear     0.792
# 5        0.00010     poly     0.080
# 6        0.00010      rbf     0.080
# 7        0.00010  sigmoid     0.080
# 8        0.00100   linear     0.792
# 9        0.00100     poly     0.149
# 10       0.00100      rbf     0.080
# 11       0.00100  sigmoid     0.080
# 12       0.01000   linear     0.792
# 13       0.01000     poly     0.450
# 14       0.01000      rbf     0.080
# 15       0.01000  sigmoid     0.080
# 16       0.10000   linear     0.792
# 17       0.10000     poly     0.656
# 18       0.10000      rbf     0.672
# 19       0.10000  sigmoid     0.522
# 20       1.00000   linear     0.792
# 21       1.00000     poly     0.736
# 22       1.00000      rbf     0.792
# 23       1.00000  sigmoid     0.453
# 24      10.00000   linear     0.792
# 25      10.00000     poly     0.777
# 26      10.00000      rbf     0.811
# 27      10.00000  sigmoid     0.414
# 28     100.00000   linear     0.792
# 29     100.00000     poly     0.779
# 30     100.00000      rbf     0.811
# 31     100.00000  sigmoid     0.395
# 32    1000.00000   linear     0.792
# 33    1000.00000     poly     0.760
# 34    1000.00000      rbf     0.811
# 35    1000.00000  sigmoid     0.393
# 36   10000.00000   linear     0.792
# 37   10000.00000     poly     0.760
# 38   10000.00000      rbf     0.811
# 39   10000.00000  sigmoid     0.392
# 40  100000.00000   linear     0.792
# 41  100000.00000     poly     0.760
# 42  100000.00000      rbf     0.811
# 43  100000.00000  sigmoid     0.392

# %%
data = results.pivot('C', 'kernel', 'accuracy')
cmap = sns.diverging_palette(10, 220, sep=80, n=10000)
ax = sns.heatmap(data, cmap=cmap)

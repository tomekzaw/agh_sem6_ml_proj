# %%
import scikitplot as skplt
from tensorflow.keras.models import load_model
from tensorflow.keras.datasets import fashion_mnist, mnist
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
(X_train_org, y_train_org), (X_test_org, y_test_org) = fashion_mnist.load_data()

X_train_org = X_train_org.reshape(-1, 28, 28, 1)
X_test_org = X_test_org.reshape(-1, 28, 28, 1)

X_train_org = X_train_org.astype('float32')
X_test_org = X_test_org.astype('float32')
X_train_org /= 255
X_test_org /= 255

# %%
X_test = X_test_org
y_test = y_test_org

# %%
model = load_model("3a/models/CNN 1 S")
y_pred = model.predict(X_test)
# Out:
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001981E346A00> and <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x000001981E382BE0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.core.Dense object at 0x000001981E3939A0> and <tensorflow.python.keras.layers.core.Dense object at 0x000001981E393CD0>).
# ...

# %%
def plot_roc(y_test, y_pred, title=None):
    ax = skplt.metrics.plot_roc(y_test, y_pred, title=title, figsize=(8, 5))
    ax.set(xlim=(-0.04, 1.04), ylim=(-0.04, 1.04))
    return ax.figure

# %%
def plot_cm(y_test, y_pred, title=None):
    ax = skplt.metrics.plot_confusion_matrix(y_test, y_pred.argmax(axis=1), normalize=True, title=title, figsize=(7, 7))
    return ax.figure

# %%
def plot_pr(y_test, y_pred, title=None):
    ax = skplt.metrics.plot_precision_recall(y_test, y_pred, figsize=(8, 6))
    return ax.figure

# %%
plot_roc(y_test, y_pred, "CNN 1 S")

# %%
plot_cm(y_test, y_pred, "CNN 1 S")

# %%
plot_pr(y_test, y_pred, "CNN 1 S").savefig('pr.svg')
